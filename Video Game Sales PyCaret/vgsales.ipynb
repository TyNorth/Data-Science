# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, Normalizer
from pycaret.clustering import *

# %%
sales = pd.read_csv('C:/Users/tnort/Documents/Datasets/vgsales.csv')
sales.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
columns = sales.columns
columns
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %%
sales.isnull().sum()
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
sales = setup(data = sales)
# Out:
# Setup Succesfully Completed!
# <style  type="text/css" >
#     #T_e7216ce6_9f91_11ea_9e46_5cf370803472row2_col1 {
#             background-color:  lightgreen;
#         }</style><table id="T_e7216ce6_9f91_11ea_9e46_5cf370803472" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e7216ce6_9f91_11ea_9e46_5cf370803472level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_e7216ce6_9f91_11ea_9e46_5cf370803472row0_col0" class="data row0 col0" >session_id </td>
#                         <td id="T_e7216ce6_9f91_11ea_9e46_5cf370803472row0_col1" class="data row0 col1" >1045</td>
#             </tr>
#             <tr>
#                         <th id="T_e7216ce6_9f91_11ea_9e46_5cf370803472level0_row1" class="row_heading level0 row1" >1</th>
# ...

# %%
sale_cluster_model = create_model(model = 'kmeans', num_clusters = 4)

# %%
assign_model(sale_cluster_model)
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
plot_model(sale_cluster_model)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
#             <div id="a8c48b1c-b897-480c-87d7-f0d2143f8b0a" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a8c48b1c-b897-480c-87d7-f0d2143f8b0a")) {
#                     Plotly.newPlot(
# ...

# %%
tuned_sales_model = tune_model(model = 'kmeans', supervised_target = 'Platform')

# %%
plot_model(tuned_sales_model)

# %%
sales.head()

# %%
save_model('vgsales_kmeans')

# %%
save_experiment('exp_05262020_vgsales')
